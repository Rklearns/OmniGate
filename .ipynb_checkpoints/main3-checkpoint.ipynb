# %%
# ============================================================
# FINAL MULTI-CANCER MULTI-OMICS PIPELINE
# ============================================================
# !pip install captum
import os
import random
import warnings
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import shap 

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.manifold import TSNE
from collections import defaultdict

# ============================================================
# CONFIG
# ============================================================

SEED = 42
MAX_EPOCHS = 500
MIN_EPOCHS = 100
PATIENCE = 45
LR = 1e-3
WEIGHT_DECAY = 5e-4

# Logic & Loss Weights
ALIGN_W = 0.2    
ORTHO_W = 0.1       
GATE_ENT_W = 0.05   
SPARSITY_W = 0.01   

OMICS_DROPOUT_P = 0.15
TOP_K_GENES = 20
DEFAULT_N_SPLITS = 5 # Renamed to allow dynamic adjustment
LATENT_DIM = 128

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(SEED)
np.random.seed(SEED)

BASE_DIR = "./preprocessing/processed_multicancer"
RESULTS_ROOT = "./results_enhanced"
os.makedirs(RESULTS_ROOT, exist_ok=True)

GS_TYPES = ["GS-BRCA", "GS-LGG", "GS-OV", "GS-COAD", "GS-GBM"]
OMICS = ["mRNA", "miRNA", "CNV", "Methy"]

# ============================================================
# 1. LOSS FUNCTIONS
# ============================================================

class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, smoothing=0.1):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.smoothing = smoothing

    def forward(self, logits, targets):
        n = logits.size(1)
        with torch.no_grad():
            true_dist = torch.zeros_like(logits)
            true_dist.fill_(self.smoothing / (n - 1))
            true_dist.scatter_(1, targets.unsqueeze(1), 1 - self.smoothing)
        log_p = F.log_softmax(logits, dim=1)
        p = torch.exp(log_p)
        focal = (1 - p) ** self.gamma
        loss = -true_dist * focal * log_p
        if self.alpha is not None:
            loss = loss * self.alpha
        return loss.sum(dim=1).mean()

def alignment_loss(zs):
    loss = 0
    for i in range(len(zs)):
        for j in range(i + 1, len(zs)):
            zi = F.normalize(zs[i], dim=1)
            zj = F.normalize(zs[j], dim=1)
            loss += 1 - (zi * zj).sum(dim=1).mean()
    return loss

def orthogonality_loss(zs):
    loss = 0
    for i in range(len(zs)):
        for j in range(i + 1, len(zs)):
            zi = F.normalize(zs[i], dim=1)
            zj = F.normalize(zs[j], dim=1)
            loss += torch.abs((zi * zj).sum(dim=1)).mean()
    return loss

def gate_entropy(g):
    eps = 1e-6
    return -(g * torch.log(g + eps) + (1 - g) * torch.log(1 - g + eps)).mean()

# ============================================================
# 2. MODEL ARCHITECTURE
# ============================================================

class OmicsEncoder(nn.Module):
    def __init__(self, in_dim, latent_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.4),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.4),
            nn.Linear(256, latent_dim),
            nn.ReLU()
        )

    def forward(self, x):
        return self.net(x)

class ContextGate(nn.Module):
    def __init__(self, context_dim, gate_dim):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(context_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, gate_dim),
            nn.Sigmoid()
        )

    def forward(self, context):
        return self.fc(context)

class GatedMultiOmicsClassifier(nn.Module):
    def __init__(self, in_dims, num_classes):
        super().__init__()
        self.encoders = nn.ModuleDict({k: OmicsEncoder(v, LATENT_DIM) for k, v in in_dims.items()})
        total_latent_dim = LATENT_DIM * len(in_dims)
        self.gates = nn.ModuleDict({k: ContextGate(total_latent_dim, LATENT_DIM) for k in in_dims})
        
        # No Projection Head (SupCon Removed)

        self.classifier = nn.Sequential(
            nn.Linear(total_latent_dim, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x_dict):
        zs_map = {m: self.encoders[m](x_dict[m]) for m in self.encoders}
        all_z_list = [zs_map[m] for m in self.encoders]
        global_context = torch.cat(all_z_list, dim=1) 
        
        zs_list = []
        gated_list = []
        gates_map = {}

        for m in self.encoders:
            z = zs_map[m]
            g = self.gates[m](global_context)
            gated_z = z * g
            zs_list.append(z)
            gated_list.append(gated_z)
            gates_map[m] = g

        fused = torch.cat(gated_list, dim=1)
        logits = self.classifier(fused)
        
        # Return 3 Values (No Proj)
        return logits, zs_list, gates_map

# ============================================================
# 3. SHAP WRAPPER
# ============================================================

class ModelWrapper(nn.Module):
    def __init__(self, model, keys):
        super().__init__()
        self.model = model
        self.keys = keys

    def forward(self, *args):
        if len(args) == 1 and isinstance(args[0], (list, tuple)):
             input_list = args[0]
        else:
             input_list = args
        x_dict = {k: t for k, t in zip(self.keys, input_list)}
        
        return self.model(x_dict)[0]

# ============================================================
# 4. TRAINING & EXPLAINABILITY
# ============================================================

def train_on_split(omics_data, y, tr, te, cancer_name, fold_idx):
    # Data Prep
    Xtr, Xte = {}, {}
    for m, X in omics_data.items():
        sc = StandardScaler()
        Xtr[m] = sc.fit_transform(X[tr])
        Xte[m] = sc.transform(X[te])

    ytr, yte = y[tr], y[te]
    Xtr_t = {m: torch.tensor(v, dtype=torch.float32).to(DEVICE) for m, v in Xtr.items()}
    Xte_t = {m: torch.tensor(v, dtype=torch.float32).to(DEVICE) for m, v in Xte.items()}
    ytr_t = torch.tensor(ytr, dtype=torch.long).to(DEVICE)

    w = compute_class_weight("balanced", classes=np.unique(ytr), y=ytr)
    w = torch.tensor(w, dtype=torch.float32).to(DEVICE)
    loss_fn = FocalLoss(alpha=w)
    
    in_dims = {m: Xtr[m].shape[1] for m in Xtr}
    model = GatedMultiOmicsClassifier(in_dims, len(np.unique(y))).to(DEVICE)
    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    best_prec, wait = 0, 0
    best_state = None

    # --- Training Loop ---
    for epoch in range(MAX_EPOCHS):
        model.train()
        opt.zero_grad()
        
        train_inputs = {k: v.clone() for k,v in Xtr_t.items()}
        if torch.rand(1).item() < OMICS_DROPOUT_P:
            drop_omics = np.random.choice(list(train_inputs.keys()))
            train_inputs[drop_omics] = torch.zeros_like(train_inputs[drop_omics])

        # UNPACK 3 VALUES (No Proj)
        logits, zs, gates = model(train_inputs)
        
        l_focal = loss_fn(logits, ytr_t) 
        l_align = ALIGN_W * alignment_loss(zs)
        l_ortho = ORTHO_W * orthogonality_loss(zs)
        l_ent = GATE_ENT_W * sum(gate_entropy(g) for g in gates.values())
        l_sparse = SPARSITY_W * sum(g.mean() for g in gates.values())

        loss = l_focal + l_align + l_ortho + l_ent + l_sparse
        loss.backward()
        opt.step()

        model.eval()
        with torch.no_grad():
            preds = model(Xte_t)[0].argmax(1).cpu().numpy()
            prec = precision_score(yte, preds, average="weighted", zero_division=0)

        if prec > best_prec:
            best_prec = prec
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            wait = 0
        else:
            wait += 1
        if epoch >= MIN_EPOCHS and wait >= PATIENCE:
            break

    model.load_state_dict({k: v.to(DEVICE) for k, v in best_state.items()})

    # ========================================================
    # EXPLAINABILITY (Diagrams included)
    # ========================================================
    
    save_dir = os.path.join(RESULTS_ROOT, cancer_name)
    os.makedirs(save_dir, exist_ok=True)
    plot_dir = os.path.join(save_dir, f"fold{fold_idx}_plots")
    os.makedirs(plot_dir, exist_ok=True)

    # 1. SHAP Analysis
    background_size = 50
    bg_inputs = [Xtr_t[m][:background_size] for m in OMICS]
    test_inputs = [Xte_t[m][:5] for m in OMICS] 
    wrapper = ModelWrapper(model, OMICS)
    
    try:
        explainer = shap.DeepExplainer(wrapper, bg_inputs)
        shap_values_full = explainer.shap_values(test_inputs, check_additivity=False)
        print(f"  > SHAP calculated successfully for Fold {fold_idx}")

        class_idx = 0 
        input_idx = 0 
        
        if isinstance(shap_values_full, list) and isinstance(shap_values_full[0], list):
             mrna_shap = shap_values_full[class_idx][input_idx]
        else:
             mrna_shap = shap_values_full[class_idx]

        mrna_features = test_inputs[input_idx].cpu().numpy()
        
        plt.figure()
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            shap.summary_plot(
                mrna_shap, 
                mrna_features, 
                feature_names=[f"Gene_{i}" for i in range(mrna_shap.shape[1])], 
                show=False, 
                max_display=20
            )
        plt.savefig(os.path.join(plot_dir, "shap_summary_mrna.png"), bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"  > SHAP skipped for Fold {fold_idx}: {e}")

    # 2. Gate Importance Diagram
    model.eval()
    with torch.no_grad():
        # UNPACK 3 VALUES
        _, _, gate_vals = model(Xte_t)
        
    gate_summary = {}
    for m in OMICS:
        avg_imp = gate_vals[m].mean().item()
        gate_summary[m] = avg_imp
        
    plt.figure(figsize=(6, 4))
    x_vals = list(gate_summary.keys())
    y_vals = list(gate_summary.values())
    sns.barplot(x=x_vals, y=y_vals, hue=x_vals, palette="viridis", legend=False)
    plt.title(f"Gate Importance (Fold {fold_idx})")
    plt.ylabel("Mean Gate Activation")
    plt.ylim(0, 1)
    plt.savefig(os.path.join(plot_dir, "gate_importance.png"))
    plt.close() 
    
    # 3. Latent Space t-SNE Diagram
    with torch.no_grad():
        zs_map = {m: model.encoders[m](Xte_t[m]) for m in OMICS}
        all_z_list = [zs_map[m] for m in OMICS]
        global_context = torch.cat(all_z_list, dim=1) 
        z_emb = global_context.cpu().numpy()
        
    if len(yte) > 10:
        try:
            tsne = TSNE(n_components=2, perplexity=min(30, len(yte)-1), random_state=SEED)
            z_tsne = tsne.fit_transform(z_emb)
            
            plt.figure(figsize=(6, 6))
            sns.scatterplot(x=z_tsne[:,0], y=z_tsne[:,1], hue=yte, palette="tab10", legend="full")
            plt.title(f"Latent Space t-SNE (Fold {fold_idx})")
            plt.savefig(os.path.join(plot_dir, "tsne_latent.png"))
            plt.close()
        except Exception as e:
            print(f"  > t-SNE skipped: {e}")

    # 4. Confusion Matrix Diagram
    with torch.no_grad():
        preds = model(Xte_t)[0].argmax(1).cpu().numpy()
    
    cm = confusion_matrix(yte, preds)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix (Fold {fold_idx})")
    plt.savefig(os.path.join(plot_dir, "confusion_matrix.png"))
    plt.close()

    # 5. Gene Sensitivity
    model.eval()
    for m in OMICS:
        inputs = Xte_t[m].clone().requires_grad_(True)
        full_inputs = {k: Xte_t[k] for k in OMICS}
        full_inputs[m] = inputs 
        
        logits, _, _ = model(full_inputs) # Expect 3
        score = logits.max(dim=1)[0].mean()
        score.backward()
        
        sens = inputs.grad.abs().mean(dim=0).cpu().numpy()
        idx = np.argsort(sens)[::-1][:TOP_K_GENES]
        
        df_genes = pd.DataFrame({"Feature_Index": idx, "Sensitivity": sens[idx]})
        out_path = os.path.join(save_dir, f"fold{fold_idx}_top_{m}_genes.csv")
        df_genes.to_csv(out_path, index=False)

    return best_prec, model

# ============================================================
# 5. MAIN LOOP
# ============================================================

if __name__ == "__main__":
    for CANCER in GS_TYPES:
        print(f"\n==================== {CANCER} ====================")
        DATA_DIR = os.path.join(BASE_DIR, CANCER)
        
        try:
            omics_data = {
                "mRNA":  np.load(os.path.join(DATA_DIR, "mRNA_processed.npy")),
                "miRNA": np.load(os.path.join(DATA_DIR, "miRNA_processed.npy")),
                "CNV":   np.load(os.path.join(DATA_DIR, "CNV_processed.npy")),
                "Methy": np.load(os.path.join(DATA_DIR, "Methy_processed.npy")),
            }
            y = np.load(os.path.join(DATA_DIR, "labels.npy"))
        except FileNotFoundError:
            print(f"Skipping {CANCER} (Files not found)")
            continue

        # DYNAMIC N_SPLITS logic
        min_class_size = np.min(np.unique(y, return_counts=True)[1])
        if min_class_size < DEFAULT_N_SPLITS:
            n_splits = max(2, min_class_size)
            print(f"  > Warning: Small class detected (n={min_class_size}). Adjusted n_splits to {n_splits}.")
        else:
            n_splits = DEFAULT_N_SPLITS

        skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
        fold_scores = []

        for i, (tr, te) in enumerate(skf.split(omics_data["mRNA"], y)):
            print(f"Fold {i}...")
            prec, model = train_on_split(omics_data, y, tr, te, CANCER, i)
            fold_scores.append(prec)
            plt.close('all')

        print(f"{CANCER} Mean Precision: {np.mean(fold_scores):.4f}")

    print("\nALL PROCESSES COMPLETED.")
# Out:
# Requirement already satisfied: captum in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (0.8.0)
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from captum) (3.9.4)
# Requirement already satisfied: numpy<2.0 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from captum) (1.26.4)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from captum) (25.0)
# Requirement already satisfied: torch>=1.10 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from captum) (2.8.0)
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from captum) (4.67.1)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from torch>=1.10->captum) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from torch>=1.10->captum) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from torch>=1.10->captum) (1.14.0)
# Requirement already satisfied: networkx in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from torch>=1.10->captum) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from torch>=1.10->captum) (3.1.6)
# Requirement already satisfied: fsspec in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from torch>=1.10->captum) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.10->captum) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from jinja2->torch>=1.10->captum) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from matplotlib->captum) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->captum) (3.23.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/mlomics/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
#
# ==================== GS-BRCA ====================
# Fold 0...
#   > SHAP calculated successfully for Fold 0
# Fold 1...
#   > SHAP calculated successfully for Fold 1
# Fold 2...
#   > SHAP calculated successfully for Fold 2
# Fold 3...
#   > SHAP calculated successfully for Fold 3
# Fold 4...
#   > SHAP calculated successfully for Fold 4
# GS-BRCA Mean Precision: 0.8882
#
# ==================== GS-LGG ====================
# Fold 0...
#   > SHAP calculated successfully for Fold 0
# Fold 1...
#   > SHAP calculated successfully for Fold 1
# Fold 2...
#   > SHAP calculated successfully for Fold 2
# Fold 3...
#   > SHAP calculated successfully for Fold 3
# Fold 4...
#   > SHAP calculated successfully for Fold 4
# GS-LGG Mean Precision: 0.9765
#
# ==================== GS-OV ====================
# Fold 0...
#   > SHAP calculated successfully for Fold 0
# Fold 1...
#   > SHAP calculated successfully for Fold 1
# Fold 2...
#   > SHAP calculated successfully for Fold 2
# Fold 3...
#   > SHAP calculated successfully for Fold 3
# Fold 4...
#   > SHAP calculated successfully for Fold 4
# GS-OV Mean Precision: 0.8827
#
# ==================== GS-COAD ====================
#   > Warning: Small class detected (n=4). Adjusted n_splits to 4.
# Fold 0...
#   > SHAP calculated successfully for Fold 0
# Fold 1...
#   > SHAP calculated successfully for Fold 1
# Fold 2...
#   > SHAP calculated successfully for Fold 2
# Fold 3...
#   > SHAP calculated successfully for Fold 3
# GS-COAD Mean Precision: 0.9442
#
# ==================== GS-GBM ====================
# Fold 0...
#   > SHAP calculated successfully for Fold 0
# Fold 1...
#   > SHAP calculated successfully for Fold 1
# Fold 2...
#   > SHAP calculated successfully for Fold 2
# Fold 3...
#   > SHAP calculated successfully for Fold 3
# Fold 4...
#   > SHAP calculated successfully for Fold 4
# GS-GBM Mean Precision: 0.8473
#
# ALL PROCESSES COMPLETED.
