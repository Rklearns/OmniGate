# %%
# Out:
# ==================== GS-BRCA ====================
# Skipping GS-BRCA (data missing)
#
# ==================== GS-LUAD ====================
# Skipping GS-LUAD (data missing)
#
# ==================== GS-COAD ====================
# Skipping GS-COAD (data missing)
#
# ==================== GS-KIRC ====================
# Skipping GS-KIRC (data missing)
#
# ==================== GS-HNSC ====================
# Skipping GS-HNSC (data missing)
#
# Pipeline completed successfully.
